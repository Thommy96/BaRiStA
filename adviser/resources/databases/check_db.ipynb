# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('restaurants_stuttgart_basic.db') 
db = pd.read_sql('select * from restaurants_stuttgart_basic', conn)
db.drop('start_location', inplace=True, axis=1)

print(db)
conn.close()
# Out:
#                              name rating  \
# 0          Restaurant Zeppelino’S    4.2
# 1    Kwan Kao - Taste of Thailand    4.7
# 2          Bocca Buona Restaurant    3.6
# 3                 CUBE Restaurant    4.3
# 4                  Carls Brauhaus    4.3
# ..                            ...    ...
# 191            HARDY'S FIRE'N'ICE    5.0
# 192                     Romantica    4.5
# 193    Tahiti - Bar & Table Dance    3,8
# 194                    Café Faust    4.7
# 195                       1.Stock    4.3
#
#                                                address  \
# 0                Arnulf-Klett-Platz 7, 70173 Stuttgart
# 1                  Rotebühlstraße 155, 70197 Stuttgart
# 2               Hauptstätter Str. 147, 70178 Stuttgart
# 3    Kleiner Schloßplatz 1 KUNSTMUSEUM, 70173 Stutt...
# 4                Stauffenbergstraße 1, 70173 Stuttgart
# ..                                                 ...
# 191                   Schwabstraße 25, 70197 Stuttgart
# 192              Hauptstätter Str. 40, 70173 Stuttgart
# 193                    Königstraße 51, 70173 Stuttgart
# 194     Geschwister-Scholl-Straße 24c, 70174 Stuttgart
# 195                    Steinstraße 13, 70173 Stuttgart
#
#                                          opening_hours website  \
# 0    {"Monday": "11:30am to 10pm", "Tuesday": "11:3...    None
# 1    {"Monday": "Closed", "Tuesday": "11:30am to 3p...    None
# 2                                                 None    None
# 3    {"Monday": "5:45 to 11pm", "Tuesday": "5:45 to...    None
# 4    {"Monday": "11am to 11pm", "Tuesday": "11am to...    None
# ..                                                 ...     ...
# 191  {"Monday": "3:30pm to 1am", "Tuesday": "3:30pm...    None
# 192  {"Sunday": "11pm to 4:30am", "Monday": "Closed...    None
# 193                                               None    None
# 194  {"Monday": "Closed", "Tuesday": "5pm to 12am",...    None
# 195  {"Monday": "Closed", "Tuesday": "Closed", "Wed...    None
#
#        phone_number        price           category
# 0      0711 2048363    Expensive        Steak house
# 1     0711 50494374     Moderate    Thai restaurant
# 2    0711 320943400         None         Restaurant
# 3      0711 2804441    Expensive         Restaurant
# 4     0711 25974611     Moderate  German restaurant
# ..              ...          ...                ...
# 191   01578 6801625         None         Hookah bar
# 192     0711 243223     Moderate                Bar
# 193            None         None                Bar
# 194   0711 68584791  Inexpensive                Bar
# 195            None         None                Bar
#
# [196 rows x 8 columns]

# %%
conn = sqlite3.connect('restaurants_stuttgart_basic.db') 
db = pd.read_sql('select * from restaurants_stuttgart_basic', conn)
db.drop('start_location', inplace=True, axis=1)

print(db)
# Out:
#                              name rating  \
# 0          Restaurant Zeppelino’S    4.2
# 1    Kwan Kao - Taste of Thailand    4.7
# 2          Bocca Buona Restaurant    3.6
# 3                 CUBE Restaurant    4.3
# 4                  Carls Brauhaus    4.3
# ..                            ...    ...
# 191            HARDY'S FIRE'N'ICE    5.0
# 192                     Romantica    4.5
# 193    Tahiti - Bar & Table Dance    3,8
# 194                    Café Faust    4.7
# 195                       1.Stock    4.3
#
#                                                address  \
# 0                Arnulf-Klett-Platz 7, 70173 Stuttgart
# 1                  Rotebühlstraße 155, 70197 Stuttgart
# 2               Hauptstätter Str. 147, 70178 Stuttgart
# 3    Kleiner Schloßplatz 1 KUNSTMUSEUM, 70173 Stutt...
# 4                Stauffenbergstraße 1, 70173 Stuttgart
# ..                                                 ...
# 191                   Schwabstraße 25, 70197 Stuttgart
# 192              Hauptstätter Str. 40, 70173 Stuttgart
# 193                    Königstraße 51, 70173 Stuttgart
# 194     Geschwister-Scholl-Straße 24c, 70174 Stuttgart
# 195                    Steinstraße 13, 70173 Stuttgart
#
#                                          opening_hours website  \
# 0    {"Monday": "11:30am to 10pm", "Tuesday": "11:3...    None
# 1    {"Monday": "Closed", "Tuesday": "11:30am to 3p...    None
# 2                                                 None    None
# 3    {"Monday": "5:45 to 11pm", "Tuesday": "5:45 to...    None
# 4    {"Monday": "11am to 11pm", "Tuesday": "11am to...    None
# ..                                                 ...     ...
# 191  {"Monday": "3:30pm to 1am", "Tuesday": "3:30pm...    None
# 192  {"Sunday": "11pm to 4:30am", "Monday": "Closed...    None
# 193                                               None    None
# 194  {"Monday": "Closed", "Tuesday": "5pm to 12am",...    None
# 195  {"Monday": "Closed", "Tuesday": "Closed", "Wed...    None
#
#        phone_number        price           category
# 0      0711 2048363    Expensive        Steak house
# 1     0711 50494374     Moderate    Thai restaurant
# 2    0711 320943400         None         Restaurant
# 3      0711 2804441    Expensive         Restaurant
# 4     0711 25974611     Moderate  German restaurant
# ..              ...          ...                ...
# 191   01578 6801625         None         Hookah bar
# 192     0711 243223     Moderate                Bar
# 193            None         None                Bar
# 194   0711 68584791  Inexpensive                Bar
# 195            None         None                Bar
#
# [196 rows x 8 columns]

# %%
conn_2 = sqlite3.connect('restaurants_stuttgart.db') 
db = pd.read_sql('select * from restaurants_stuttgart', conn_2)
print(db)
conn.close()
# Out:
#                              name rating num_reviews  \
# 0          Restaurant Zeppelino’S    4.2         169
# 1    Kwan Kao - Taste of Thailand    4.7         566
# 2          Bocca Buona Restaurant    3.6         139
# 3                 CUBE Restaurant    4.3       1,048
# 4                  Carls Brauhaus    4.3       6,498
# ..                            ...    ...         ...
# 191            HARDY'S FIRE'N'ICE    5.0          69
# 192                     Romantica    4.5         217
# 193    Tahiti - Bar & Table Dance    3,8         173
# 194                    Café Faust    4.7         111
# 195                       1.Stock    4.3          69
#
#                                                 manner  \
# 0     ["Serves dine-in", "No takeaway", "No delivery"]
# 1    ["Serves dine-in", "Offers kerbside pickup", "...
# 2    ["Serves dine-in", "Offers kerbside pickup", "...
# 3     ["Serves dine-in", "No takeaway", "No delivery"]
# 4    ["Serves dine-in", "Offers takeaway", "Has no-...
# ..                                                 ...
# 191                  ["Serves dine-in", "No delivery"]
# 192   ["Serves dine-in", "No takeaway", "No delivery"]
# 193  ["Verzehr im Restaurant", "Keine Speisen/Getr\...
# 194       ["No dine-in", "No takeaway", "No delivery"]
# 195   ["Serves dine-in", "No takeaway", "No delivery"]
#
#                                            description  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    Modern dishes with Asian & Mediterranean flavo...
# 4    Roast meats & schnitzels, plus breakfasts, in ...
# ..                                                 ...
# 191                                               None
# 192  Small, high-energy dance club with DJs playing...
# 193                                               None
# 194                                               None
# 195                                               None
#
#                                                address  \
# 0                Arnulf-Klett-Platz 7, 70173 Stuttgart
# 1                  Rotebühlstraße 155, 70197 Stuttgart
# 2               Hauptstätter Str. 147, 70178 Stuttgart
# 3    Kleiner Schloßplatz 1 KUNSTMUSEUM, 70173 Stutt...
# 4                Stauffenbergstraße 1, 70173 Stuttgart
# ..                                                 ...
# 191                   Schwabstraße 25, 70197 Stuttgart
# 192              Hauptstätter Str. 40, 70173 Stuttgart
# 193                    Königstraße 51, 70173 Stuttgart
# 194     Geschwister-Scholl-Straße 24c, 70174 Stuttgart
# 195                    Steinstraße 13, 70173 Stuttgart
#
#                   coordinate  \
# 0    [48.7834137, 9.1799585]
# 1    [48.7694447, 9.1542506]
# 2    [48.7645378, 9.1699027]
# 3                       None
# 4    [48.7793589, 9.1802132]
# ..                       ...
# 191  [48.7694591, 9.1586655]
# 192  [48.7726083, 9.1781504]
# 193  [48.7734328, 9.1753066]
# 194  [48.7828767, 9.1757687]
# 195  [48.7736129, 9.1766393]
#
#                                          opening_hours website  \
# 0    {"Sunday": "11:30am to 10pm", "Monday": "11:30...    None
# 1    {"Sunday": "5 to 9pm", "Monday": "Closed", "Tu...    None
# 2                                                 None    None
# 3    {"Sunday": "11:45am to 4:45pm", "Monday": "11:...    None
# 4    {"Sunday": "10am to 10pm", "Monday": "11am to ...    None
# ..                                                 ...     ...
# 191  {"Sunday": "3:30pm to 1am", "Monday": "3:30pm ...    None
# 192  {"Sunday": "11pm to 4:30am", "Monday": "Closed...    None
# 193                                               None    None
# 194  {"Sunday": "Closed", "Monday": "Closed", "Tues...    None
# 195  {"Sunday": "Closed", "Monday": "Closed", "Tues...    None
#
#        phone_number                                            reviews  \
# 0      0711 2048363  ["A bit overpriced, but great staff.", "Nice f...
# 1     0711 50494374  ["Good menu selections, fresh food, friendly s...
# 2    0711 320943400  ["Generous food, good service (special thumbs ...
# 3      0711 2804441  ["Food and drinks are good, prices are reasona...
# 4     0711 25974611  ["Good food and a good atmosphere, a nice plac...
# ..              ...                                                ...
# 191   01578 6801625                                                 []
# 192     0711 243223  ["Tiny, but cozy basement club with excellent ...
# 193            None  ["T\u00fcrsteher, Dj, Kassierer und Barpersona...
# 194   0711 68584791  ["Very chill good for students to hangout frie...
# 195            None                                                 []
#
#            price           category  \
# 0      Expensive        Steak house
# 1       Moderate    Thai restaurant
# 2           None         Restaurant
# 3      Expensive         Restaurant
# 4       Moderate  German restaurant
# ..           ...                ...
# 191         None         Hookah bar
# 192     Moderate                Bar
# 193         None                Bar
# 194  Inexpensive                Bar
# 195         None                Bar
#
#                                             table_size parking_lot  \
# 0    [[[7, 2], [9, 3], [7, 3], [6, 2], [10, 2], [9,...           1
# 1    [[[6, 1], [8, 2], [6, 3], [2, 1], [7, 2], [6, ...           0
# 2                                                 None           0
# 3    [[[7, 1], [9, 3], [5, 3], [8, 3]], [[6, 3], [2...           1
# 4    [[[2, 1], [7, 2], [6, 3]], [[9, 3], [6, 3], [3...           1
# ..                                                 ...         ...
# 191  [[[6, 1], [8, 1], [6, 1], [6, 2], [9, 2], [2, ...           0
# 192  [[[10, 3], [9, 2], [3, 2], [5, 3], [3, 1], [10...           1
# 193                                               None           0
# 194  [[[8, 1], [2, 3], [8, 2], [10, 1], [7, 3], [9,...           1
# 195  [[[1, 1], [6, 2], [4, 1], [3, 3], [5, 2], [8, ...           0
#
#     start_location
# 0    Schwabstrasse
# 1              Uni
# 2     Hauptbahnhof
# 3     Hauptbahnhof
# 4     Hauptbahnhof
# ..             ...
# 191  Schwabstrasse
# 192            Uni
# 193            Uni
# 194            Uni
# 195  Schwabstrasse
#
# [196 rows x 16 columns]

# %%
conn = sqlite3.connect('restaurants_stuttgart_basic.db') 
db = pd.read_sql('select * from restaurants_stuttgart_basic', conn)
db.drop('start_location', inplace=True, axis=1)

print(db)
# Out:
#                              name rating  \
# 0          Restaurant Zeppelino’S    4.2
# 1    Kwan Kao - Taste of Thailand    4.7
# 2          Bocca Buona Restaurant    3.6
# 3                 CUBE Restaurant    4.3
# 4                  Carls Brauhaus    4.3
# ..                            ...    ...
# 191            HARDY'S FIRE'N'ICE    5.0
# 192                     Romantica    4.5
# 193    Tahiti - Bar & Table Dance    3,8
# 194                    Café Faust    4.7
# 195                       1.Stock    4.3
#
#                                                address  \
# 0                Arnulf-Klett-Platz 7, 70173 Stuttgart
# 1                  Rotebühlstraße 155, 70197 Stuttgart
# 2               Hauptstätter Str. 147, 70178 Stuttgart
# 3    Kleiner Schloßplatz 1 KUNSTMUSEUM, 70173 Stutt...
# 4                Stauffenbergstraße 1, 70173 Stuttgart
# ..                                                 ...
# 191                   Schwabstraße 25, 70197 Stuttgart
# 192              Hauptstätter Str. 40, 70173 Stuttgart
# 193                    Königstraße 51, 70173 Stuttgart
# 194     Geschwister-Scholl-Straße 24c, 70174 Stuttgart
# 195                    Steinstraße 13, 70173 Stuttgart
#
#                                          opening_hours website  \
# 0    {"Monday": "11:30am to 10pm", "Tuesday": "11:3...    None
# 1    {"Monday": "Closed", "Tuesday": "11:30am to 3p...    None
# 2                                                 None    None
# 3    {"Monday": "5:45 to 11pm", "Tuesday": "5:45 to...    None
# 4    {"Monday": "11am to 11pm", "Tuesday": "11am to...    None
# ..                                                 ...     ...
# 191  {"Monday": "3:30pm to 1am", "Tuesday": "3:30pm...    None
# 192  {"Sunday": "11pm to 4:30am", "Monday": "Closed...    None
# 193                                               None    None
# 194  {"Monday": "Closed", "Tuesday": "5pm to 12am",...    None
# 195  {"Monday": "Closed", "Tuesday": "Closed", "Wed...    None
#
#        phone_number        price           category
# 0      0711 2048363    Expensive        Steak house
# 1     0711 50494374     Moderate    Thai restaurant
# 2    0711 320943400         None         Restaurant
# 3      0711 2804441    Expensive         Restaurant
# 4     0711 25974611     Moderate  German restaurant
# ..              ...          ...                ...
# 191   01578 6801625         None         Hookah bar
# 192     0711 243223     Moderate                Bar
# 193            None         None                Bar
# 194   0711 68584791  Inexpensive                Bar
# 195            None         None                Bar
#
# [196 rows x 8 columns]

# %%
conn = sqlite3.connect('restaurants_stuttgart_basic.db') 
db = pd.read_sql('select * from restaurants_stuttgart_basic', conn)
zip(db.name, db.address)
dict(zip(db.name, db.address))
# Out:
# {'Restaurant Zeppelino’S': 'Arnulf-Klett-Platz 7, 70173 Stuttgart',
#  'Kwan Kao - Taste of Thailand': 'Rotebühlstraße 155, 70197 Stuttgart',
#  'Bocca Buona Restaurant': 'Hauptstätter Str. 147, 70178 Stuttgart',
#  'CUBE Restaurant': 'Kleiner Schloßplatz 1 KUNSTMUSEUM, 70173 Stuttgart',
#  'Carls Brauhaus': 'Stauffenbergstraße 1, 70173 Stuttgart',
#  'La Bamboo': 'Schwabstraße 129, 70193 Stuttgart',
#  "DO's Vietnam Street Food": 'Tübinger Str. 15, 70178 Stuttgart',
#  'Speisekammer West': 'Rosenbergstraße 89, 70193 Stuttgart',
#  'Trattoria Riva': 'Senefelderstraße 21, 70178 Stuttgart',
#  'BURREATOS': 'Hospitalstraße 19, 70174 Stuttgart',
#  'Italiani ( ma non troppo )': 'Mailänder Platz 23, 70173 Stuttgart',
#  'Amici': 'Lautenschlagerstraße 2, 70173 Stuttgart',
#  "Ochs'n Willi": 'Kleiner Schloßplatz 4, 70173 Stuttgart',
#  'Le Tonneau Bistro': 'Schwabstraße 92, 70193 Stuttgart',
#  'AMADEUS Restaurant & Bar': 'Charlottenpl. 17, 70173 Stuttgart',
#  'Restaurant Achillion': 'Schwabstraße 32, 70197 Stuttgart',
#  'local eat': 'Schloßstraße 55, 70176 Stuttgart',
#  "Lion's Restaurant Stuttgart": 'Parlerstraße 86, 70192 Stuttgart',
#  'Brauereigaststätte Dinkelacker': 'Tübinger Str. 46, 70178 Stuttgart',
#  'MAMMA MIA! Ristorante': 'Theodor-Heuss-Straße 14, 70174 Stuttgart',
#  'Restaurant Weissenhof': 'Heilbronner Str. 21, 70191 Stuttgart',
#  'Jose y Josefina': 'Gutenbergstraße 87, 70197 Stuttgart',
#  'Mauritius Stuttgart-Mitte': 'Marienstraße 12, 70178 Stuttgart',
#  'Krua Thai Bolan Thairestaurant': 'Rotebühlstraße 159, 70197 Stuttgart',
#  'CITIZEN LONG': 'Am Fruchtkasten 3, 70173 Stuttgart',
#  'Hans im Glück': 'Marienstraße 3B, 70178 Stuttgart',
#  'Ritzi Stuttgart': 'Friedrichstraße 6, 70174 Stuttgart',
#  'Wirtshaus zum Hotzenplotz': 'Silberburgstraße 88, 70176 Stuttgart',
#  'Weinstube Kachelofen': 'Eingang, Eberhardstraße, Töpferstraße 10, 70173 Stuttgart',
#  'Raman Restaurant': 'Charlottenstraße 40, 70182 Stuttgart',
#  'Vietal Kitchen Stuttgart': 'Landhausstraße 181, 70188 Stuttgart',
#  'Vetter Essen & Trinken': 'Bopserstraße 18, 70180 Stuttgart',
#  'La Bruschetta': 'Weberstraße 108, 70182 Stuttgart',
#  'Vegi Stuttgart': 'Steinstraße 13, 70173 Stuttgart',
#  'Esszimmer': 'Eugenstraße 16, 70182 Stuttgart',
#  'Little Italy Restaurant': 'Liststraße 30, 70180 Stuttgart',
#  'Cavallino Spaghettaro': 'Leuschnerstraße 17, 70174 Stuttgart',
#  'Imbiss Beirut': 'Josef-Hirn-Platz 8, 70173 Stuttgart',
#  'Makamba': 'Schlosserstraße 16, 70180 Stuttgart',
#  "The Gardener's Nosh": 'Calwer Str. 62, 70173 Stuttgart',
#  'Wilma Wunder Stuttgart': 'Rotebühlpl. 21, 70178 Stuttgart',
#  'Onkel Otto': 'Böblinger Str. 14, 70178 Stuttgart',
#  'Sen Viet Restaurant': 'Stöckachstraße 59, 70190 Stuttgart',
#  'Ristorante Goldoni': 'Reinsburgstraße 151, 70197 Stuttgart',
#  'Restaurant Aspendos': 'Neckarstraße 98, 70190 Stuttgart',
#  "ABACCO'S STEAKHOUSE Stuttgart": 'Rotebühlpl. 10, 70173 Stuttgart',
#  'Restaurant Le Cassoulet': 'Willy-Brandt-Straße 30, 70173 Stuttgart',
#  'Perbacco': 'Tübinger Str. 41-43, 70178 Stuttgart',
#  'VAPIANO Stuttgart Bolzstrasse': 'Bolzstraße 7, 70173 Stuttgart',
#  'Empore': 'Dorotheenstraße 4, 70173 Stuttgart',
#  'Ganesha Restaurant': '19, Lembergstraße, 70186 Stuttgart',
#  'KuaiStyle Restaurant': 'Hirschstraße 27, 70173 Stuttgart',
#  "Joe Peña's Stuttgart": 'Kriegsbergstraße 15, 70174 Stuttgart',
#  'Viet Wok': 'Kronenstraße 45, 70174 Stuttgart',
#  'Schnitzelkönig Stuttgart': 'Bebelstraße 96, 70193 Stuttgart',
#  'Il Pomodoro Wilhelmsplatz S-Mitte': 'Wilhelmspl. 4, 70182 Stuttgart',
#  'Noir Cuisine': 'Tübinger Str. 92, 70178 Stuttgart',
#  'Mozzarella Bar Stuttgart': 'Paulinenstraße 16, 70178 Stuttgart',
#  'La Fenice Stuttgart': 'Rotebühlplatz 29 / Ecke, Sophienstraße, 70178 Stuttgart',
#  'Safran Restaurant Stuttgart': 'Schloßstraße 57A, 70176 Stuttgart',
#  'Gasthaus Bären': 'Paulinenstraße 45, 70178 Stuttgart',
#  'Greek Cuisine': 'Eberhardstraße 41, 70173 Stuttgart',
#  'CHITO & GVRITO': 'Heinrich-Baumann-Straße 23, 70190 Stuttgart',
#  'Tay Ho': 'Rathauspassage 7, 70173 Stuttgart',
#  'Ambiente Africa': 'Werastraße 1, 70182 Stuttgart',
#  'Tokio Dining': 'Steubenstraße 12, 70190 Stuttgart',
#  'Keyaki Japanese Cuisine': 'Katharinenstraße 5, 70182 Stuttgart',
#  'NETZER': 'Herzogstraße 4, 70176 Stuttgart',
#  'Restaurant Bosporus': 'Kernerpl. 5, 70182 Stuttgart',
#  'Restaurant Kronprinz': 'Neckarstraße 124, 70190 Stuttgart',
#  'Injeera Restaurant': 'Wagnerstraße 30, 70182 Stuttgart',
#  'Restaurant Lässig': 'Gerokstraße 12, 70188 Stuttgart',
#  'Pilli- Pilli': 'Ludwigstraße 13, 70176 Stuttgart',
#  'Gaststätte Wohnzimmer': 'Schloßstraße 77, 70176 Stuttgart',
#  'Don Via Restaurant Stuttgart': 'Theodor-Heuss-Straße 14, 70174 Stuttgart',
#  'Valle': 'Geschwister-Scholl-Straße 3, 70174 Stuttgart',
#  'Kikuya Japanese Restaurant': 'Calwer Str. 31, 70173 Stuttgart',
#  'Sichuan China Restaurant': 'Bebelstraße 27, 70193 Stuttgart',
#  'Platzhirsch': 'Geißstraße 12, 70173 Stuttgart',
#  'Il Ristorante Villa Rustica': 'Gablenberger Hauptstraße 20, 70186 Stuttgart',
#  'Mandu': 'Fritz-Elsas-Straße 60, 70174 Stuttgart',
#  'Zeppelin Stüble': 'Arnulf-Klett-Platz 7, 70173 Stuttgart',
#  'D. Carlos Restaurante': 'Hauptstätter Str. 120, 70178 Stuttgart',
#  'Nannina': 'Gaishämmerstraße 14, 70186 Stuttgart',
#  'Restaurant Rôtisserie': 'Seidenstraße 34, 70174 Stuttgart',
#  'Arslan’s Kebap Stuttgart Mitte': 'Marienstraße 28, 70178 Stuttgart',
#  'Shima Restaurant': 'Olgastraße 86, 70180 Stuttgart',
#  "Kim's So Korean Food": 'Neue Brücke 8, 70173 Stuttgart',
#  'Paulaner am alten Postplatz': 'Calwer Str. 45, 70173 Stuttgart',
#  'Restaurant Kleinschmeckerei Stuttgart': 'Am, Kernerpl. 9/10, 70173 Stuttgart',
#  'Gravity': 'Tunzhofer Str. 3, 70191 Stuttgart',
#  'Taverna Yol': 'Spittastraße 2, 70193 Stuttgart',
#  'CAVOS Taverna': 'Lautenschlagerstraße 20, 70173 Stuttgart',
#  'Restaurant Girasole': 'Schwabstraße 114, 70193 Stuttgart',
#  'Restaurant Rösch': 'Scheffelstraße 23, 70193 Stuttgart',
#  'Namaste India am Berlinerplatz Liederhalle Stuttgart': 'Schloßstraße 53A, 70176 Stuttgart',
#  'Thai Thaani Restaurant': 'Neckarstraße 246, 70190 Stuttgart',
#  'Tevhid Restaurant': 'Neckarstraße 160, 70190 Stuttgart',
#  'Tasca im Feui': 'Haußmannstraße 235, 70188 Stuttgart',
#  'BAR': 'Augustenstraße 81, 70178 Stuttgart',
#  'Biddy Earlys Irish Pub': 'Marienstraße 28, 70178 Stuttgart',
#  'Jigger & Spoon': 'Gymnasiumstraße 33, 70174 Stuttgart',
#  'Donkey Monkey Shots Bar': 'Königstraße 51, 70173 Stuttgart',
#  'Piano Bar': 'Seidenstraße 34, 70174 Stuttgart',
#  'Wolfram Bar & Terrace': 'Wolframstraße 41, 70191 Stuttgart',
#  'Bar Lillet': 'Willy-Brandt-Straße 30, 70173 Stuttgart',
#  'Lennart Bar': 'Tübinger Str. 109, 70178 Stuttgart',
#  'Torhaus Zwanzig BAR & LOUNGE': 'Torstraße 20, 70173 Stuttgart',
#  'BARBADOS Stuttgart': 'Rotebühlpl. 37, 70178 Stuttgart',
#  'Pils-Pub Alt Stuttgart Sky Sportsbar': 'Sophienstraße 33, 70178 Stuttgart',
#  'Tequila Bar GRANDE': 'Friedrichstraße 41, 70174 Stuttgart',
#  'W13 Bar & Kitchen': 'Wilhelmstraße 13, 70182 Stuttgart',
#  'Minibar': 'Paulinenstraße 8, 70178 Stuttgart',
#  'Schwarz Weiß Bar': 'Wilhelmstraße 8A, 70182 Stuttgart',
#  'Detroit Bar': 'Geißstraße 5, 70173 Stuttgart',
#  "Eduard's Bar Stuttgart": 'Sporerstraße 16, 70173 Stuttgart',
#  'Billardsaal': 'Marienstraße 5, 70178 Stuttgart',
#  'Tequila Bar': 'Steinstraße 15, 70173 Stuttgart',
#  'Le petit Coq': 'Hauptstätter Str. 59, 70178 Stuttgart',
#  'Mon Ami Bar': 'Wagenburgstraße 104, 70186 Stuttgart',
#  'The Corner': 'Wilhelmstraße 1, 70372 Stuttgart',
#  'Havana Cafe & Cocktail Stuttgart': 'Paulinenstraße 49, 70178 Stuttgart',
#  'California Bounge': 'Börsenplatz 1, 70174 Stuttgart',
#  'BLAU': 'Breitscheidstraße 133, 70176 Stuttgart',
#  'UHU Bar': 'Leonhardstraße 4, 70182 Stuttgart',
#  'reBOOTS': 'Bopserstraße 9, 70180 Stuttgart',
#  'o.T. Bar Lounge': 'Kleiner Schloßplatz 1, 70173 Stuttgart',
#  'Yart': 'Königstraße 47/3. Etage, 70173 Stuttgart',
#  'Delicious Bar': 'Christophstraße 14, 70178 Stuttgart (Gerberviertel)',
#  'Sportcafé Carambolage in Stuttgart am Feuersee': 'Rotebühlstraße 81, 70178 Stuttgart',
#  'Westend Eckkneipe': 'Bebelstraße 36, 70193 Stuttgart',
#  "Nur's cafe bar": 'Olgastraße 97a, 70180 Stuttgart',
#  'FOU FOU | Cocktail- und Champagnerbar': 'Leonhardstraße 13, 70182 Stuttgart',
#  "JACK'S LIVING ROOM": 'Kernerpl. 9, 70182 Stuttgart',
#  'Lido Bar': 'Weberstraße, 70182 Stuttgart',
#  'Mrs. Jones': 'Geißstraße 8, 70173 Stuttgart',
#  'Bar Tabu': 'Weberstraße 5B, 70182 Stuttgart',
#  'BAR BAR': 'Gutenbergstraße 29, 70176 Stuttgart',
#  'Bar Korridor': 'Weberstraße 11d, 70182 Stuttgart',
#  'O`Reilly`s Irish Pub': 'Reuchlinstraße 27/29, 70176 Stuttgart',
#  'Sportsbar Max & Moritz S-Ost': 'Ostendstraße 106, 70188 Stuttgart',
#  'Paul & George': 'Weberstraße 3, 70182 Stuttgart',
#  'Momona Cafe And Bar': 'Marienplatz 4, 70178 Stuttgart',
#  'Laternchen': 'Reuchlinstraße 26, 70176 Stuttgart',
#  'Oblomow': 'Torstraße 20, 70173 Stuttgart',
#  'Waranga': 'Kleiner Schloßplatz 15, 70173 Stuttgart',
#  'Mietbar Stuttgart': 'Schulstraße 3, 70173 Stuttgart',
#  'Bar Scala': 'Heilbronner Str. 21, 70191 Stuttgart',
#  'Bierkneipe Wikinger': 'Charlottenstraße 6, 70173 Stuttgart',
#  "Paddy's Irish Pub": 'Pfarrstraße 25, 70182 Stuttgart',
#  'Ribingurumu': 'Theodor-Heuss-Straße 4, 70174 Stuttgart',
#  'Zum Dortmunder': 'Silberburgstraße 132, 70176 Stuttgart',
#  'Caffè-Bar': 'Torstraße 27, 70173 Stuttgart',
#  'Hanky Panky': 'Sophienstraße 3, 70180 Stuttgart',
#  'Long bar': 'Rotebühlpl. 11, 70178 Stuttgart',
#  'Elegance Bar': 'Waiblinger Str. 12, 70372 Stuttgart',
#  'Dafni’s Bistro-Pub': 'Böblinger Str. 181A, 70199 Stuttgart',
#  'Taubenstüble': 'Taubenstraße 7, 70199 Stuttgart',
#  'Immer Beer Herzen': 'Hauptstätter Str. 45, 70173 Stuttgart',
#  'Botanical Affairs': 'Weberstraße 10, 70182 Stuttgart',
#  'mocha Espresso & wine': 'Tübinger Str. 20, 70178 Stuttgart',
#  'TinTin': 'Neue Weinsteige 8, 70180 Stuttgart',
#  'Dilayla': 'Eberhardstraße 49, 70173 Stuttgart',
#  'Aha! Cafe & Bar': 'Neue Brücke 6, 70173 Stuttgart',
#  'El Teatro - Cocktails • Cigars • Tastings': 'Stephanstraße 33, 70173 Stuttgart',
#  'DMC Bar': 'Spreuergasse 16, 70372 Stuttgart',
#  'Holzmaler': 'Weberstraße, 70182 Stuttgart',
#  'Sky Beach Stuttgart': 'Sky Beach, Königstraße 6, 70173 Stuttgart',
#  'Extra Omnes': 'Sophienstraße 32, 70178 Stuttgart',
#  'Kap Tormentoso': 'Hirschstraße 27, 70173 Stuttgart',
#  "Monroe's": 'Schulstraße 3, 70173 Stuttgart',
#  'Mata Hari': 'Geißstraße 3, 70173 Stuttgart',
#  'John Cranko Lounge': 'Schillerstraße 23, 70173 Stuttgart',
#  'SAUSALITOS': 'Marienstraße 3B, 70178 Stuttgart',
#  'The Private Room': 'Lange Str. 35, 70174 Stuttgart',
#  'Ruby Bar Stuttgart': 'Königstraße 49, 70173 Stuttgart',
#  'Mr.Shisha Bar & Lounge': 'Hauptstätter Str. 40, 70173 Stuttgart',
#  'Tom’s Bar Stuttgart': 'Pfarrstraße 13, 70182 Stuttgart',
#  'Piano Café Lysdorss': 'Rötestraße 44, 70197 Stuttgart',
#  'Schirmstüble': 'Immenhofer Str. 1, 70180 Stuttgart',
#  'Amber Club Lounge': 'Forststraße 9, 70174 Stuttgart',
#  'NONNE Shisha Bar Lounge': 'Leonhardstraße 9, 70182 Stuttgart',
#  'Classic Rock Café': 'Schellingstraße 7, 70174 Stuttgart',
#  'Danny’s Bar & Grill': 'Schulstraße 12A, 70173 Stuttgart',
#  'Caffebar Hölderlin': 'Schwabstraße 197, 70193 Stuttgart',
#  '7grad club': 'Theodor-Heuss-Straße 32, 70174 Stuttgart',
#  'Bistro Treffpunkt': 'Schwarenbergstraße, 70188 Stuttgart',
#  'Marshall Matt': 'Eberhardstraße 6, A, 70173 Stuttgart',
#  'Royal Café Bar': 'Gablenberger Hauptstraße 1, 70186 Stuttgart',
#  'Suessholz': 'Wilhelmspl. 3, 70182 Stuttgart',
#  'Fais Dodo': 'Rotebühlpl. 33, 70178 Stuttgart',
#  "HARDY'S FIRE'N'ICE": 'Schwabstraße 25, 70197 Stuttgart',
#  'Romantica': 'Hauptstätter Str. 40, 70173 Stuttgart',
#  'Tahiti - Bar & Table Dance': 'Königstraße 51, 70173 Stuttgart',
#  'Café Faust': 'Geschwister-Scholl-Straße 24c, 70174 Stuttgart',
#  '1.Stock': 'Steinstraße 13, 70173 Stuttgart'}
